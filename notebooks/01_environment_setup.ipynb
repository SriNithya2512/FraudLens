# %%
# !git clone https://github.com/SriNithya2512/FraudLens.git
# Out:
# Cloning into 'FraudLens'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 18 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 6.02 KiB | 6.02 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd FraudLens
# Out:
# /content/FraudLens

# %%
# !ls -R
# Out:
# .:
# data  models  notebooks  paper	README.md  results  src
#
# ./data:
# raw
#
# ./data/raw:
#
# ./models:
#
# ./notebooks:
#
# ./paper:
#
# ./results:
#
# ./src:

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 2.11.0+cu128
# 12.8

# %%
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.5 MB/s eta 0:00:00
# ...

# %%
# !pip install pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv \
    -f https://data.pyg.org/whl/torch-2.11.0+cu128.html
# Out:
# Looking in links: https://data.pyg.org/whl/torch-2.11.0+cu128.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 58.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 105.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 136.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 115.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch_spline_conv: filename=torch_spline_conv-1.2.2-cp312-cp312-linux_x86_64.whl size=718525 sha256=0cd652f052c270d2e8aa2e8af774422b33d212d500329b55c7b4c30ad03ac9b5
#   Stored in directory: /root/.cache/pip/wheels/54/7a/2e/46a729dc0aad2da1a908b0d2ac86ab127d73e6b4310a945d07
# Successfully built torch_spline_conv
# ...

# %%
# !pip install xgboost shap pandas scikit-learn networkx matplotlib seaborn

# %%
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
# Out:
# CUDA available: True
# Device: Tesla T4

# %%
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv

edge_index = torch.tensor([[0, 1, 1, 2],
                            [1, 0, 2, 1]], dtype=torch.long)
x = torch.tensor([[1.0], [2.0], [3.0]])

data = Data(x=x, edge_index=edge_index)
conv = GCNConv(in_channels=1, out_channels=4)
out = conv(data.x, data.edge_index)
print(out.shape)
# Out:
# torch.Size([3, 4])

# %%
import os
os.environ['KAGGLE_API_TOKEN'] = 'KGAT_347aa35ee04d9e3b18d3896eda94332f'

# !kaggle datasets download -d ellipticco/elliptic-data-set
# !unzip -o elliptic-data-set.zip -d data/raw/
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/ellipticco/elliptic-data-set
# License(s): Attribution-NonCommercial-NoDerivatives 4.0 International (CC BY-NC-ND 4.0)
# elliptic-data-set.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  elliptic-data-set.zip
#   inflating: data/raw/elliptic_bitcoin_dataset/elliptic_txs_classes.csv
#   inflating: data/raw/elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv
#   inflating: data/raw/elliptic_bitcoin_dataset/elliptic_txs_features.csv

# %%
import pandas as pd

base_path = "data/raw/elliptic_bitcoin_dataset/"

feats = pd.read_csv(base_path + "elliptic_txs_features.csv", header=None)
classes = pd.read_csv(base_path + "elliptic_txs_classes.csv")
edges = pd.read_csv(base_path + "elliptic_txs_edgelist.csv")

print("Features shape:", feats.shape)
print("Classes shape:", classes.shape)
print("Edges shape:", edges.shape)
print(classes['class'].value_counts())
# Out:
# Features shape: (203769, 167)
# Classes shape: (203769, 2)
# Edges shape: (234355, 2)
# class
# unknown    157205
# 2           42019
# 1            4545
# Name: count, dtype: int64

# %%
# !git add .
# !git commit -m "Day 1: environment setup, verified GPU/PyG install, loaded and confirmed Elliptic dataset class imbalance"
# !git push
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@116e883e375e.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git config --global user.email "srinithya2509@gmail.com"
# !git config --global user.name "SriNithya2512"

# %%
# !git add .
# !git commit -m "Day 1: environment setup, verified GPU/PyG install, loaded and confirmed Elliptic dataset class imbalance"
# !git push
# Out:
# [main c694aeb] Day 1: environment setup, verified GPU/PyG install, loaded and confirmed Elliptic dataset class imbalance
#  4 files changed, 438126 insertions(+)
#  create mode 100644 data/raw/elliptic_bitcoin_dataset/elliptic_txs_classes.csv
#  create mode 100644 data/raw/elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv
#  create mode 100644 data/raw/elliptic_bitcoin_dataset/elliptic_txs_features.csv
#  create mode 100644 elliptic-data-set.zip
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# Remove the files from git tracking (keeps them on disk, just untracks them)
# !git rm -r --cached data/raw/
# !git rm --cached elliptic-data-set.zip

# Add a .gitignore so this doesn't happen again
with open(".gitignore", "w") as f:
    f.write("data/raw/\n*.zip\n")

# !git add .gitignore
# !git commit -m "Untrack raw dataset files, add gitignore"
# Out:
# rm 'data/raw/.gitkeep'
# rm 'data/raw/elliptic_bitcoin_dataset/elliptic_txs_classes.csv'
# rm 'data/raw/elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv'
# rm 'data/raw/elliptic_bitcoin_dataset/elliptic_txs_features.csv'
# rm 'elliptic-data-set.zip'
# [main 547a2ac] Untrack raw dataset files, add gitignore
#  6 files changed, 2 insertions(+), 438127 deletions(-)
#  create mode 100644 .gitignore
#  delete mode 100644 data/raw/.gitkeep
#  delete mode 100644 data/raw/elliptic_bitcoin_dataset/elliptic_txs_classes.csv
#  delete mode 100644 data/raw/elliptic_bitcoin_dataset/elliptic_txs_edgelist.csv
#  delete mode 100644 data/raw/elliptic_bitcoin_dataset/elliptic_txs_features.csv
#  delete mode 100644 elliptic-data-set.zip

# %%
#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

# !git remote set-url origin https://SriNithya2512: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@github.com/SriNithya2512/FraudLens.git
# !git push
# Out:
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (12/12), 288.55 MiB | 18.39 MiB/s, done.
# Total 12 (delta 2), reused 1 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 1 local object.
# remote: error: Trace: 34adfcaa49220ec28a6250cebe1b32c5144803eae6905de72b9abf1a2cca21e0
# remote: error: See https://gh.io/lfs for more information.
# remote: error: File elliptic-data-set.zip is 146.12 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: File data/raw/elliptic_bitcoin_dataset/elliptic_txs_features.csv is 657.73 MB; this exceeds GitHub's file size limit of 100.00 MB
# remote: error: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/SriNithya2512/FraudLens.git
#  ! [remote rejected] main -> main (pre-receive hook declined)
# ...

# %%
# !pwd
# Out:
# /content/FraudLens

# %%
# Make sure the raw data files are excluded going forward
with open(".gitignore", "w") as f:
    f.write("data/raw/\n*.zip\n*.csv\n")

# Wipe git history and start clean
# !rm -rf .git
# !git init
# !git add .
# !git commit -m "Day 1: environment setup, verified GPU/PyG install, confirmed Elliptic dataset class imbalance"
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/FraudLens/.git/
# [master (root-commit) 0f31cbb] Day 1: environment setup, verified GPU/PyG install, confirmed Elliptic dataset class imbalance
#  7 files changed, 9 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 README.md
#  create mode 100644 models/.gitkeep
#  create mode 100644 notebooks/.gitkeep
#  create mode 100644 paper/.gitkeep
#  create mode 100644 results/.gitkeep
#  create mode 100644 src/.gitkeep

# %%
# !git branch -M main
# !git remote add origin https://SriNithya2512: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@github.com/SriNithya2512/FraudLens.git
# !git push -u origin main --force
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (6/6), 477 bytes | 477.00 KiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/SriNithya2512/FraudLens.git
#  + 72f510e...0f31cbb main -> main (forced update)
# Branch 'main' set up to track remote branch 'main' from 'origin'.
